# %% [markdown]
# # This is markdown
#
# ## This is sub header
#
# - this is used to create bullet points
# - use - and then shift enter to execute the nb cell

# %%
print("Hello from jupyter")
# Out:
# Hello from jupyter

# %%
a = 10
b = 5

sum = a +b

print(f"the sum of {a} and {b} is {sum}")
# Out:
# the sum of 10 and 5 is 15

# %%
print("Hello")
# Out:
# Hello
